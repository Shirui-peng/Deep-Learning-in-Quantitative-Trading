# %% [markdown]
# # Chapter 5.2
#
# We now demonstrate the deep momenum strategy. We use a simply fully connected network and optimize sharpe ratio.

# %%
import os 
import sys
current_dir = os.path.dirname(os.path.abspath("__file__"))
project_dir = os.path.dirname(current_dir)
sys.path.append(project_dir)

import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd 
from Utilis.early_stopper import EarlyStopping
from Utilis.loss import SharpeLoss
from Utilis.metrics import report_metrics

torch.manual_seed(42)
np.random.seed(42)

# %%
class MLP(nn.Module):
    def __init__(self, seq_length, n_features):
        super(MLP, self).__init__()
        self.flat_dim = seq_length * n_features
        self.net = nn.Sequential(
            nn.Flatten(),                   # (batch, seq_length*n_features)
            nn.Linear(self.flat_dim, 64),
            nn.Softsign(),
            nn.Linear(64, 32),
            nn.Softsign(),
            nn.Linear(32, 1),
            nn.Softsign()             
        )
    def forward(self, x):
        return self.net(x)
    
def train_model(model, X_train, y_train, X_val, y_val, X_test,
                savepath, epochs=5, lr=1e-3, batch_size=12, patience=5):
    optimizer = optim.Adam(model.parameters(), lr=lr)
    criterion = SharpeLoss()

    dataset = torch.utils.data.TensorDataset(X_train, y_train)
    dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True)
    
    early_stopper = EarlyStopping(savepath=savepath, patience=patience, min_delta=1e-4, verbose=True)

    for epoch in range(epochs):
        model.train()
        epoch_loss = 0.0

        for batch_X, batch_y in dataloader:
            optimizer.zero_grad()
            out = model(batch_X)
            loss = criterion(out, batch_y)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item() * batch_X.size(0)

        epoch_loss /= len(dataloader.dataset)
        model.eval()
        with torch.no_grad():
            y_pred_val = model(X_val)
            val_loss = criterion(y_pred_val, y_val).item()

        print(f"Epoch {epoch+1}/{epochs}, "
              f"Train loss: {epoch_loss:.4f}, "
              f"Validation loss: {val_loss:.4f}")
        
        early_stopper(model, val_loss)
        if early_stopper.early_stop:
            print("Early stopping triggered!")
            break
    
    model.load_state_dict(torch.load(savepath))
    model.eval()
    y_pred_test = model(X_test)    
    return model, y_pred_test.detach().cpu().numpy()

# %%
def data_classification(X, Y, T):
    [N, D] = X.shape
    df = np.array(X)
    dY = np.array(Y)
    dataY = dY[T - 1:N]
    dataX = np.zeros((N - T + 1, T, D))
    for i in range(T, N + 1):
        dataX[i - T] = df[i - T:i, :]
    return dataX, dataY

def create_TSMOM(price):
    past_year_return = price.pct_change(252)
    position = np.sign(past_year_return)
    return position

def create_SMA(price, k1, k2):
    price_k1 = price.rolling(k1).mean()
    price_k2 = price.rolling(k2).mean()
    position = price_k1 - price_k2
    return position / position.rolling(k2).std()

def create_MACD(price, k1, k2):
    price_k1 = price.ewm(k1).mean()
    price_k2 = price.ewm(k2).mean()
    position = price_k1 - price_k2
    position = position / position.rolling(k2).std()
    return position

# %%
df = pd.read_csv('../Data/aapl.csv')
df['returns'] = np.log(df['Close']/df['Close'].shift(1))
df = df.drop(columns=['Ticker'])
df.head()
# Out:
#       Close      High       Low      Open     Volume   returns
# 0  0.771149  0.832276  0.761274  0.814408  512377600       NaN
# 1  0.782433  0.831806  0.774910  0.780552  778321600  0.014527
# 2  0.714723  0.805004  0.714723  0.798421  767972800 -0.090514
# 3  0.748578  0.759864  0.718485  0.726008  460734400  0.046281
# 4  0.735412  0.769267  0.712842  0.767386  505064000 -0.017745

# %%
# Use a rolling window to normalize the data
def create_x_features(df):
    df['ret_1'] = np.log(df['Close']/df['Close'].shift(1))
    df['TSMOM'] = create_TSMOM(df['Close'])
    df['SMA'] = create_SMA(df['Close'], 10, 40)
    df['MACD1'] = create_MACD(df['Close'], 8, 24)
    df['MACD2'] = create_MACD(df['Close'], 16, 48)
    df['MACD3'] = create_MACD(df['Close'], 32, 96)
    df_nor = df[['ret_1', 'TSMOM', 'SMA', 'MACD1', 'MACD2', 'MACD3']].fillna(0)
    return df_nor

# %%
df_nor = create_x_features(df)
df_x, df_y = data_classification(df_nor[:-1], df['returns'][1:], T=10)
print(df_x.shape, df_y.shape)
# Out:
# (6277, 10, 6) (6277,)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
train_size = int(0.6 * len(df_x))
val_size = int(0.8 * len(df_x))

x_train = torch.tensor(np.array(df_x[:train_size]), dtype=torch.float32).to(device)
y_train = torch.tensor(np.array(df_y[:train_size]), dtype=torch.float32).to(device)

x_val = torch.tensor(np.array(df_x[train_size:val_size]), dtype=torch.float32).to(device)
y_val = torch.tensor(np.array(df_y[train_size:val_size]), dtype=torch.float32).to(device)

x_test = torch.tensor(np.array(df_x[val_size:]), dtype=torch.float32).to(device)
y_test = np.array(df_y[val_size:])

print(x_train.shape, y_train.shape)
print(x_val.shape, y_val.shape)
print(x_test.shape, y_test.shape)
# Out:
# Using device: cpu
# torch.Size([3766, 10, 6]) torch.Size([3766])
# torch.Size([1255, 10, 6]) torch.Size([1255])
# torch.Size([1256, 10, 6]) (1256,)

# %%
mlp_model = MLP(seq_length=10, n_features=6).to(device)
mlp_model, y_pred = train_model(mlp_model, x_train, y_train, x_val, y_val, x_test, epochs=1000, patience=100, lr=0.0001, batch_size=128, savepath='model/best_mlp')
# Out:
# Epoch 1/1000, Train loss: -0.0076, Validation loss: -0.0377
# Epoch 2/1000, Train loss: -0.0201, Validation loss: -0.0387
# Validation loss improved. Resetting counter.
# Epoch 3/1000, Train loss: -0.0255, Validation loss: -0.0404
# Validation loss improved. Resetting counter.
# Epoch 4/1000, Train loss: -0.0235, Validation loss: -0.0429
# Validation loss improved. Resetting counter.
# Epoch 5/1000, Train loss: -0.0298, Validation loss: -0.0461
# Validation loss improved. Resetting counter.
# Epoch 6/1000, Train loss: -0.0324, Validation loss: -0.0501
# Validation loss improved. Resetting counter.
# Epoch 7/1000, Train loss: -0.0383, Validation loss: -0.0521
# Validation loss improved. Resetting counter.
# Epoch 8/1000, Train loss: -0.0365, Validation loss: -0.0529
# Validation loss improved. Resetting counter.
# Epoch 9/1000, Train loss: -0.0448, Validation loss: -0.0536
# Validation loss improved. Resetting counter.
# Epoch 10/1000, Train loss: -0.0387, Validation loss: -0.0538
# Validation loss improved. Resetting counter.
# Epoch 11/1000, Train loss: -0.0385, Validation loss: -0.0542
# Validation loss improved. Resetting counter.
# Epoch 12/1000, Train loss: -0.0393, Validation loss: -0.0544
# Validation loss improved. Resetting counter.
# Epoch 13/1000, Train loss: -0.0372, Validation loss: -0.0547
# Validation loss improved. Resetting counter.
# Epoch 14/1000, Train loss: -0.0372, Validation loss: -0.0548
# Validation loss improved. Resetting counter.
# Epoch 15/1000, Train loss: -0.0390, Validation loss: -0.0549
# Validation loss improved. Resetting counter.
# Epoch 16/1000, Train loss: -0.0378, Validation loss: -0.0550
# No improvement in validation loss. Counter: 1/100
# Epoch 17/1000, Train loss: -0.0397, Validation loss: -0.0551
# Validation loss improved. Resetting counter.
# Epoch 18/1000, Train loss: -0.0360, Validation loss: -0.0552
# No improvement in validation loss. Counter: 1/100
# Epoch 19/1000, Train loss: -0.0394, Validation loss: -0.0553
# Validation loss improved. Resetting counter.
# Epoch 20/1000, Train loss: -0.0359, Validation loss: -0.0553
# No improvement in validation loss. Counter: 1/100
# Epoch 21/1000, Train loss: -0.0365, Validation loss: -0.0553
# No improvement in validation loss. Counter: 2/100
# Epoch 22/1000, Train loss: -0.0401, Validation loss: -0.0554
# Validation loss improved. Resetting counter.
# Epoch 23/1000, Train loss: -0.0395, Validation loss: -0.0555
# No improvement in validation loss. Counter: 1/100
# Epoch 24/1000, Train loss: -0.0436, Validation loss: -0.0556
# Validation loss improved. Resetting counter.
# Epoch 25/1000, Train loss: -0.0393, Validation loss: -0.0556
# No improvement in validation loss. Counter: 1/100
# Epoch 26/1000, Train loss: -0.0397, Validation loss: -0.0556
# No improvement in validation loss. Counter: 2/100
# Epoch 27/1000, Train loss: -0.0388, Validation loss: -0.0557
# Validation loss improved. Resetting counter.
# Epoch 28/1000, Train loss: -0.0398, Validation loss: -0.0557
# No improvement in validation loss. Counter: 1/100
# Epoch 29/1000, Train loss: -0.0436, Validation loss: -0.0557
# No improvement in validation loss. Counter: 2/100
# Epoch 30/1000, Train loss: -0.0374, Validation loss: -0.0558
# No improvement in validation loss. Counter: 3/100
# Epoch 31/1000, Train loss: -0.0365, Validation loss: -0.0558
# Validation loss improved. Resetting counter.
# Epoch 32/1000, Train loss: -0.0389, Validation loss: -0.0558
# No improvement in validation loss. Counter: 1/100
# Epoch 33/1000, Train loss: -0.0406, Validation loss: -0.0559
# No improvement in validation loss. Counter: 2/100
# Epoch 34/1000, Train loss: -0.0370, Validation loss: -0.0559
# No improvement in validation loss. Counter: 3/100
# Epoch 35/1000, Train loss: -0.0416, Validation loss: -0.0559
# No improvement in validation loss. Counter: 4/100
# Epoch 36/1000, Train loss: -0.0439, Validation loss: -0.0559
# No improvement in validation loss. Counter: 5/100
# Epoch 37/1000, Train loss: -0.0422, Validation loss: -0.0559
# No improvement in validation loss. Counter: 6/100
# Epoch 38/1000, Train loss: -0.0379, Validation loss: -0.0559
# No improvement in validation loss. Counter: 7/100
# Epoch 39/1000, Train loss: -0.0370, Validation loss: -0.0559
# No improvement in validation loss. Counter: 8/100
# Epoch 40/1000, Train loss: -0.0441, Validation loss: -0.0559
# Validation loss improved. Resetting counter.
# Epoch 41/1000, Train loss: -0.0368, Validation loss: -0.0560
# No improvement in validation loss. Counter: 1/100
# Epoch 42/1000, Train loss: -0.0391, Validation loss: -0.0560
# No improvement in validation loss. Counter: 2/100
# Epoch 43/1000, Train loss: -0.0376, Validation loss: -0.0560
# No improvement in validation loss. Counter: 3/100
# Epoch 44/1000, Train loss: -0.0376, Validation loss: -0.0560
# No improvement in validation loss. Counter: 4/100
# Epoch 45/1000, Train loss: -0.0395, Validation loss: -0.0560
# No improvement in validation loss. Counter: 5/100
# Epoch 46/1000, Train loss: -0.0361, Validation loss: -0.0560
# No improvement in validation loss. Counter: 6/100
# Epoch 47/1000, Train loss: -0.0409, Validation loss: -0.0560
# No improvement in validation loss. Counter: 7/100
# Epoch 48/1000, Train loss: -0.0416, Validation loss: -0.0560
# No improvement in validation loss. Counter: 8/100
# Epoch 49/1000, Train loss: -0.0396, Validation loss: -0.0560
# Validation loss improved. Resetting counter.
# Epoch 50/1000, Train loss: -0.0347, Validation loss: -0.0560
# No improvement in validation loss. Counter: 1/100
# Epoch 51/1000, Train loss: -0.0366, Validation loss: -0.0560
# No improvement in validation loss. Counter: 2/100
# Epoch 52/1000, Train loss: -0.0363, Validation loss: -0.0560
# No improvement in validation loss. Counter: 3/100
# Epoch 53/1000, Train loss: -0.0363, Validation loss: -0.0561
# No improvement in validation loss. Counter: 4/100
# Epoch 54/1000, Train loss: -0.0373, Validation loss: -0.0561
# No improvement in validation loss. Counter: 5/100
# Epoch 55/1000, Train loss: -0.0402, Validation loss: -0.0561
# No improvement in validation loss. Counter: 6/100
# Epoch 56/1000, Train loss: -0.0377, Validation loss: -0.0561
# No improvement in validation loss. Counter: 7/100
# Epoch 57/1000, Train loss: -0.0441, Validation loss: -0.0559
# No improvement in validation loss. Counter: 8/100
# Epoch 58/1000, Train loss: -0.0371, Validation loss: -0.0560
# No improvement in validation loss. Counter: 9/100
# Epoch 59/1000, Train loss: -0.0384, Validation loss: -0.0561
# No improvement in validation loss. Counter: 10/100
# Epoch 60/1000, Train loss: -0.0428, Validation loss: -0.0561
# No improvement in validation loss. Counter: 11/100
# Epoch 61/1000, Train loss: -0.0435, Validation loss: -0.0560
# No improvement in validation loss. Counter: 12/100
# Epoch 62/1000, Train loss: -0.0409, Validation loss: -0.0561
# No improvement in validation loss. Counter: 13/100
# Epoch 63/1000, Train loss: -0.0428, Validation loss: -0.0561
# No improvement in validation loss. Counter: 14/100
# Epoch 64/1000, Train loss: -0.0377, Validation loss: -0.0561
# No improvement in validation loss. Counter: 15/100
# Epoch 65/1000, Train loss: -0.0372, Validation loss: -0.0561
# No improvement in validation loss. Counter: 16/100
# Epoch 66/1000, Train loss: -0.0395, Validation loss: -0.0561
# No improvement in validation loss. Counter: 17/100
# Epoch 67/1000, Train loss: -0.0425, Validation loss: -0.0561
# No improvement in validation loss. Counter: 18/100
# Epoch 68/1000, Train loss: -0.0389, Validation loss: -0.0561
# Validation loss improved. Resetting counter.
# Epoch 69/1000, Train loss: -0.0384, Validation loss: -0.0562
# No improvement in validation loss. Counter: 1/100
# Epoch 70/1000, Train loss: -0.0425, Validation loss: -0.0562
# No improvement in validation loss. Counter: 2/100
# Epoch 71/1000, Train loss: -0.0466, Validation loss: -0.0562
# No improvement in validation loss. Counter: 3/100
# Epoch 72/1000, Train loss: -0.0411, Validation loss: -0.0562
# No improvement in validation loss. Counter: 4/100
# Epoch 73/1000, Train loss: -0.0414, Validation loss: -0.0562
# No improvement in validation loss. Counter: 5/100
# Epoch 74/1000, Train loss: -0.0379, Validation loss: -0.0562
# No improvement in validation loss. Counter: 6/100
# Epoch 75/1000, Train loss: -0.0379, Validation loss: -0.0562
# No improvement in validation loss. Counter: 7/100
# Epoch 76/1000, Train loss: -0.0458, Validation loss: -0.0561
# No improvement in validation loss. Counter: 8/100
# Epoch 77/1000, Train loss: -0.0376, Validation loss: -0.0561
# No improvement in validation loss. Counter: 9/100
# Epoch 78/1000, Train loss: -0.0425, Validation loss: -0.0562
# No improvement in validation loss. Counter: 10/100
# Epoch 79/1000, Train loss: -0.0406, Validation loss: -0.0562
# No improvement in validation loss. Counter: 11/100
# Epoch 80/1000, Train loss: -0.0402, Validation loss: -0.0562
# No improvement in validation loss. Counter: 12/100
# Epoch 81/1000, Train loss: -0.0416, Validation loss: -0.0562
# No improvement in validation loss. Counter: 13/100
# Epoch 82/1000, Train loss: -0.0396, Validation loss: -0.0562
# No improvement in validation loss. Counter: 14/100
# Epoch 83/1000, Train loss: -0.0390, Validation loss: -0.0562
# No improvement in validation loss. Counter: 15/100
# Epoch 84/1000, Train loss: -0.0345, Validation loss: -0.0562
# No improvement in validation loss. Counter: 16/100
# Epoch 85/1000, Train loss: -0.0405, Validation loss: -0.0562
# No improvement in validation loss. Counter: 17/100
# Epoch 86/1000, Train loss: -0.0379, Validation loss: -0.0562
# No improvement in validation loss. Counter: 18/100
# Epoch 87/1000, Train loss: -0.0380, Validation loss: -0.0562
# No improvement in validation loss. Counter: 19/100
# Epoch 88/1000, Train loss: -0.0409, Validation loss: -0.0561
# No improvement in validation loss. Counter: 20/100
# Epoch 89/1000, Train loss: -0.0378, Validation loss: -0.0562
# No improvement in validation loss. Counter: 21/100
# Epoch 90/1000, Train loss: -0.0435, Validation loss: -0.0562
# No improvement in validation loss. Counter: 22/100
# Epoch 91/1000, Train loss: -0.0375, Validation loss: -0.0562
# No improvement in validation loss. Counter: 23/100
# Epoch 92/1000, Train loss: -0.0370, Validation loss: -0.0562
# No improvement in validation loss. Counter: 24/100
# Epoch 93/1000, Train loss: -0.0375, Validation loss: -0.0562
# No improvement in validation loss. Counter: 25/100
# Epoch 94/1000, Train loss: -0.0373, Validation loss: -0.0562
# No improvement in validation loss. Counter: 26/100
# Epoch 95/1000, Train loss: -0.0375, Validation loss: -0.0562
# No improvement in validation loss. Counter: 27/100
# Epoch 96/1000, Train loss: -0.0425, Validation loss: -0.0562
# Validation loss improved. Resetting counter.
# Epoch 97/1000, Train loss: -0.0416, Validation loss: -0.0563
# No improvement in validation loss. Counter: 1/100
# Epoch 98/1000, Train loss: -0.0370, Validation loss: -0.0563
# No improvement in validation loss. Counter: 2/100
# Epoch 99/1000, Train loss: -0.0397, Validation loss: -0.0563
# No improvement in validation loss. Counter: 3/100
# Epoch 100/1000, Train loss: -0.0443, Validation loss: -0.0562
# No improvement in validation loss. Counter: 4/100
# Epoch 101/1000, Train loss: -0.0392, Validation loss: -0.0560
# No improvement in validation loss. Counter: 5/100
# Epoch 102/1000, Train loss: -0.0395, Validation loss: -0.0562
# No improvement in validation loss. Counter: 6/100
# Epoch 103/1000, Train loss: -0.0385, Validation loss: -0.0563
# No improvement in validation loss. Counter: 7/100
# Epoch 104/1000, Train loss: -0.0365, Validation loss: -0.0563
# No improvement in validation loss. Counter: 8/100
# Epoch 105/1000, Train loss: -0.0385, Validation loss: -0.0563
# No improvement in validation loss. Counter: 9/100
# Epoch 106/1000, Train loss: -0.0354, Validation loss: -0.0563
# No improvement in validation loss. Counter: 10/100
# Epoch 107/1000, Train loss: -0.0417, Validation loss: -0.0563
# No improvement in validation loss. Counter: 11/100
# Epoch 108/1000, Train loss: -0.0390, Validation loss: -0.0563
# No improvement in validation loss. Counter: 12/100
# Epoch 109/1000, Train loss: -0.0403, Validation loss: -0.0563
# No improvement in validation loss. Counter: 13/100
# Epoch 110/1000, Train loss: -0.0391, Validation loss: -0.0563
# No improvement in validation loss. Counter: 14/100
# Epoch 111/1000, Train loss: -0.0381, Validation loss: -0.0563
# No improvement in validation loss. Counter: 15/100
# Epoch 112/1000, Train loss: -0.0393, Validation loss: -0.0563
# No improvement in validation loss. Counter: 16/100
# Epoch 113/1000, Train loss: -0.0340, Validation loss: -0.0563
# No improvement in validation loss. Counter: 17/100
# Epoch 114/1000, Train loss: -0.0409, Validation loss: -0.0563
# No improvement in validation loss. Counter: 18/100
# Epoch 115/1000, Train loss: -0.0409, Validation loss: -0.0562
# No improvement in validation loss. Counter: 19/100
# Epoch 116/1000, Train loss: -0.0435, Validation loss: -0.0563
# No improvement in validation loss. Counter: 20/100
# Epoch 117/1000, Train loss: -0.0365, Validation loss: -0.0563
# No improvement in validation loss. Counter: 21/100
# Epoch 118/1000, Train loss: -0.0418, Validation loss: -0.0563
# No improvement in validation loss. Counter: 22/100
# Epoch 119/1000, Train loss: -0.0414, Validation loss: -0.0563
# No improvement in validation loss. Counter: 23/100
# Epoch 120/1000, Train loss: -0.0401, Validation loss: -0.0563
# No improvement in validation loss. Counter: 24/100
# Epoch 121/1000, Train loss: -0.0417, Validation loss: -0.0563
# No improvement in validation loss. Counter: 25/100
# Epoch 122/1000, Train loss: -0.0413, Validation loss: -0.0563
# No improvement in validation loss. Counter: 26/100
# Epoch 123/1000, Train loss: -0.0390, Validation loss: -0.0563
# No improvement in validation loss. Counter: 27/100
# Epoch 124/1000, Train loss: -0.0369, Validation loss: -0.0563
# No improvement in validation loss. Counter: 28/100
# Epoch 125/1000, Train loss: -0.0384, Validation loss: -0.0563
# No improvement in validation loss. Counter: 29/100
# Epoch 126/1000, Train loss: -0.0428, Validation loss: -0.0563
# No improvement in validation loss. Counter: 30/100
# Epoch 127/1000, Train loss: -0.0417, Validation loss: -0.0563
# No improvement in validation loss. Counter: 31/100
# Epoch 128/1000, Train loss: -0.0374, Validation loss: -0.0563
# No improvement in validation loss. Counter: 32/100
# Epoch 129/1000, Train loss: -0.0424, Validation loss: -0.0563
# No improvement in validation loss. Counter: 33/100
# Epoch 130/1000, Train loss: -0.0410, Validation loss: -0.0563
# No improvement in validation loss. Counter: 34/100
# Epoch 131/1000, Train loss: -0.0404, Validation loss: -0.0563
# No improvement in validation loss. Counter: 35/100
# Epoch 132/1000, Train loss: -0.0416, Validation loss: -0.0563
# No improvement in validation loss. Counter: 36/100
# Epoch 133/1000, Train loss: -0.0366, Validation loss: -0.0563
# No improvement in validation loss. Counter: 37/100
# Epoch 134/1000, Train loss: -0.0358, Validation loss: -0.0563
# No improvement in validation loss. Counter: 38/100
# Epoch 135/1000, Train loss: -0.0384, Validation loss: -0.0563
# No improvement in validation loss. Counter: 39/100
# Epoch 136/1000, Train loss: -0.0355, Validation loss: -0.0563
# No improvement in validation loss. Counter: 40/100
# Epoch 137/1000, Train loss: -0.0399, Validation loss: -0.0563
# No improvement in validation loss. Counter: 41/100
# Epoch 138/1000, Train loss: -0.0407, Validation loss: -0.0562
# No improvement in validation loss. Counter: 42/100
# Epoch 139/1000, Train loss: -0.0363, Validation loss: -0.0563
# No improvement in validation loss. Counter: 43/100
# Epoch 140/1000, Train loss: -0.0407, Validation loss: -0.0563
# No improvement in validation loss. Counter: 44/100
# Epoch 141/1000, Train loss: -0.0429, Validation loss: -0.0563
# No improvement in validation loss. Counter: 45/100
# Epoch 142/1000, Train loss: -0.0454, Validation loss: -0.0563
# No improvement in validation loss. Counter: 46/100
# Epoch 143/1000, Train loss: -0.0370, Validation loss: -0.0563
# No improvement in validation loss. Counter: 47/100
# Epoch 144/1000, Train loss: -0.0357, Validation loss: -0.0563
# No improvement in validation loss. Counter: 48/100
# Epoch 145/1000, Train loss: -0.0409, Validation loss: -0.0563
# No improvement in validation loss. Counter: 49/100
# Epoch 146/1000, Train loss: -0.0383, Validation loss: -0.0563
# No improvement in validation loss. Counter: 50/100
# Epoch 147/1000, Train loss: -0.0417, Validation loss: -0.0563
# No improvement in validation loss. Counter: 51/100
# Epoch 148/1000, Train loss: -0.0373, Validation loss: -0.0563
# No improvement in validation loss. Counter: 52/100
# Epoch 149/1000, Train loss: -0.0388, Validation loss: -0.0563
# No improvement in validation loss. Counter: 53/100
# Epoch 150/1000, Train loss: -0.0401, Validation loss: -0.0563
# No improvement in validation loss. Counter: 54/100
# Epoch 151/1000, Train loss: -0.0406, Validation loss: -0.0563
# No improvement in validation loss. Counter: 55/100
# Epoch 152/1000, Train loss: -0.0359, Validation loss: -0.0563
# No improvement in validation loss. Counter: 56/100
# Epoch 153/1000, Train loss: -0.0399, Validation loss: -0.0564
# Validation loss improved. Resetting counter.
# Epoch 154/1000, Train loss: -0.0400, Validation loss: -0.0563
# No improvement in validation loss. Counter: 1/100
# Epoch 155/1000, Train loss: -0.0422, Validation loss: -0.0564
# No improvement in validation loss. Counter: 2/100
# Epoch 156/1000, Train loss: -0.0390, Validation loss: -0.0564
# No improvement in validation loss. Counter: 3/100
# Epoch 157/1000, Train loss: -0.0403, Validation loss: -0.0564
# No improvement in validation loss. Counter: 4/100
# Epoch 158/1000, Train loss: -0.0410, Validation loss: -0.0564
# No improvement in validation loss. Counter: 5/100
# Epoch 159/1000, Train loss: -0.0382, Validation loss: -0.0563
# No improvement in validation loss. Counter: 6/100
# Epoch 160/1000, Train loss: -0.0427, Validation loss: -0.0562
# No improvement in validation loss. Counter: 7/100
# Epoch 161/1000, Train loss: -0.0412, Validation loss: -0.0563
# No improvement in validation loss. Counter: 8/100
# Epoch 162/1000, Train loss: -0.0386, Validation loss: -0.0564
# No improvement in validation loss. Counter: 9/100
# Epoch 163/1000, Train loss: -0.0405, Validation loss: -0.0564
# No improvement in validation loss. Counter: 10/100
# Epoch 164/1000, Train loss: -0.0403, Validation loss: -0.0564
# No improvement in validation loss. Counter: 11/100
# Epoch 165/1000, Train loss: -0.0427, Validation loss: -0.0564
# No improvement in validation loss. Counter: 12/100
# Epoch 166/1000, Train loss: -0.0379, Validation loss: -0.0563
# No improvement in validation loss. Counter: 13/100
# Epoch 167/1000, Train loss: -0.0407, Validation loss: -0.0564
# No improvement in validation loss. Counter: 14/100
# Epoch 168/1000, Train loss: -0.0430, Validation loss: -0.0564
# No improvement in validation loss. Counter: 15/100
# Epoch 169/1000, Train loss: -0.0383, Validation loss: -0.0564
# No improvement in validation loss. Counter: 16/100
# Epoch 170/1000, Train loss: -0.0380, Validation loss: -0.0564
# No improvement in validation loss. Counter: 17/100
# Epoch 171/1000, Train loss: -0.0404, Validation loss: -0.0564
# No improvement in validation loss. Counter: 18/100
# Epoch 172/1000, Train loss: -0.0419, Validation loss: -0.0564
# No improvement in validation loss. Counter: 19/100
# Epoch 173/1000, Train loss: -0.0441, Validation loss: -0.0564
# No improvement in validation loss. Counter: 20/100
# Epoch 174/1000, Train loss: -0.0384, Validation loss: -0.0564
# No improvement in validation loss. Counter: 21/100
# Epoch 175/1000, Train loss: -0.0420, Validation loss: -0.0563
# No improvement in validation loss. Counter: 22/100
# Epoch 176/1000, Train loss: -0.0384, Validation loss: -0.0564
# No improvement in validation loss. Counter: 23/100
# Epoch 177/1000, Train loss: -0.0393, Validation loss: -0.0564
# No improvement in validation loss. Counter: 24/100
# Epoch 178/1000, Train loss: -0.0409, Validation loss: -0.0564
# No improvement in validation loss. Counter: 25/100
# Epoch 179/1000, Train loss: -0.0397, Validation loss: -0.0564
# No improvement in validation loss. Counter: 26/100
# Epoch 180/1000, Train loss: -0.0395, Validation loss: -0.0564
# No improvement in validation loss. Counter: 27/100
# Epoch 181/1000, Train loss: -0.0349, Validation loss: -0.0563
# No improvement in validation loss. Counter: 28/100
# Epoch 182/1000, Train loss: -0.0396, Validation loss: -0.0561
# No improvement in validation loss. Counter: 29/100
# Epoch 183/1000, Train loss: -0.0372, Validation loss: -0.0563
# No improvement in validation loss. Counter: 30/100
# Epoch 184/1000, Train loss: -0.0380, Validation loss: -0.0557
# No improvement in validation loss. Counter: 31/100
# Epoch 185/1000, Train loss: -0.0399, Validation loss: -0.0563
# No improvement in validation loss. Counter: 32/100
# Epoch 186/1000, Train loss: -0.0379, Validation loss: -0.0564
# No improvement in validation loss. Counter: 33/100
# Epoch 187/1000, Train loss: -0.0382, Validation loss: -0.0564
# No improvement in validation loss. Counter: 34/100
# Epoch 188/1000, Train loss: -0.0453, Validation loss: -0.0564
# No improvement in validation loss. Counter: 35/100
# Epoch 189/1000, Train loss: -0.0398, Validation loss: -0.0564
# No improvement in validation loss. Counter: 36/100
# Epoch 190/1000, Train loss: -0.0385, Validation loss: -0.0564
# No improvement in validation loss. Counter: 37/100
# Epoch 191/1000, Train loss: -0.0367, Validation loss: -0.0564
# No improvement in validation loss. Counter: 38/100
# Epoch 192/1000, Train loss: -0.0377, Validation loss: -0.0564
# No improvement in validation loss. Counter: 39/100
# Epoch 193/1000, Train loss: -0.0411, Validation loss: -0.0564
# No improvement in validation loss. Counter: 40/100
# Epoch 194/1000, Train loss: -0.0384, Validation loss: -0.0564
# No improvement in validation loss. Counter: 41/100
# Epoch 195/1000, Train loss: -0.0409, Validation loss: -0.0564
# No improvement in validation loss. Counter: 42/100
# Epoch 196/1000, Train loss: -0.0419, Validation loss: -0.0564
# No improvement in validation loss. Counter: 43/100
# Epoch 197/1000, Train loss: -0.0405, Validation loss: -0.0564
# No improvement in validation loss. Counter: 44/100
# Epoch 198/1000, Train loss: -0.0404, Validation loss: -0.0564
# No improvement in validation loss. Counter: 45/100
# Epoch 199/1000, Train loss: -0.0370, Validation loss: -0.0564
# No improvement in validation loss. Counter: 46/100
# Epoch 200/1000, Train loss: -0.0382, Validation loss: -0.0564
# No improvement in validation loss. Counter: 47/100
# Epoch 201/1000, Train loss: -0.0376, Validation loss: -0.0564
# No improvement in validation loss. Counter: 48/100
# Epoch 202/1000, Train loss: -0.0436, Validation loss: -0.0564
# No improvement in validation loss. Counter: 49/100
# Epoch 203/1000, Train loss: -0.0368, Validation loss: -0.0564
# No improvement in validation loss. Counter: 50/100
# Epoch 204/1000, Train loss: -0.0410, Validation loss: -0.0564
# No improvement in validation loss. Counter: 51/100
# Epoch 205/1000, Train loss: -0.0361, Validation loss: -0.0564
# No improvement in validation loss. Counter: 52/100
# Epoch 206/1000, Train loss: -0.0378, Validation loss: -0.0564
# No improvement in validation loss. Counter: 53/100
# Epoch 207/1000, Train loss: -0.0393, Validation loss: -0.0564
# No improvement in validation loss. Counter: 54/100
# Epoch 208/1000, Train loss: -0.0401, Validation loss: -0.0564
# No improvement in validation loss. Counter: 55/100
# Epoch 209/1000, Train loss: -0.0399, Validation loss: -0.0564
# No improvement in validation loss. Counter: 56/100
# Epoch 210/1000, Train loss: -0.0402, Validation loss: -0.0564
# No improvement in validation loss. Counter: 57/100
# Epoch 211/1000, Train loss: -0.0397, Validation loss: -0.0564
# No improvement in validation loss. Counter: 58/100
# Epoch 212/1000, Train loss: -0.0403, Validation loss: -0.0564
# No improvement in validation loss. Counter: 59/100
# Epoch 213/1000, Train loss: -0.0387, Validation loss: -0.0564
# No improvement in validation loss. Counter: 60/100
# Epoch 214/1000, Train loss: -0.0390, Validation loss: -0.0564
# No improvement in validation loss. Counter: 61/100
# Epoch 215/1000, Train loss: -0.0453, Validation loss: -0.0564
# No improvement in validation loss. Counter: 62/100
# Epoch 216/1000, Train loss: -0.0411, Validation loss: -0.0564
# No improvement in validation loss. Counter: 63/100
# Epoch 217/1000, Train loss: -0.0392, Validation loss: -0.0564
# No improvement in validation loss. Counter: 64/100
# Epoch 218/1000, Train loss: -0.0374, Validation loss: -0.0564
# No improvement in validation loss. Counter: 65/100
# Epoch 219/1000, Train loss: -0.0384, Validation loss: -0.0564
# No improvement in validation loss. Counter: 66/100
# Epoch 220/1000, Train loss: -0.0426, Validation loss: -0.0564
# No improvement in validation loss. Counter: 67/100
# Epoch 221/1000, Train loss: -0.0422, Validation loss: -0.0564
# No improvement in validation loss. Counter: 68/100
# Epoch 222/1000, Train loss: -0.0434, Validation loss: -0.0564
# No improvement in validation loss. Counter: 69/100
# Epoch 223/1000, Train loss: -0.0385, Validation loss: -0.0564
# No improvement in validation loss. Counter: 70/100
# Epoch 224/1000, Train loss: -0.0435, Validation loss: -0.0564
# No improvement in validation loss. Counter: 71/100
# Epoch 225/1000, Train loss: -0.0416, Validation loss: -0.0564
# No improvement in validation loss. Counter: 72/100
# Epoch 226/1000, Train loss: -0.0404, Validation loss: -0.0564
# No improvement in validation loss. Counter: 73/100
# Epoch 227/1000, Train loss: -0.0427, Validation loss: -0.0564
# No improvement in validation loss. Counter: 74/100
# Epoch 228/1000, Train loss: -0.0424, Validation loss: -0.0564
# No improvement in validation loss. Counter: 75/100
# Epoch 229/1000, Train loss: -0.0344, Validation loss: -0.0564
# No improvement in validation loss. Counter: 76/100
# Epoch 230/1000, Train loss: -0.0393, Validation loss: -0.0564
# No improvement in validation loss. Counter: 77/100
# Epoch 231/1000, Train loss: -0.0423, Validation loss: -0.0564
# No improvement in validation loss. Counter: 78/100
# Epoch 232/1000, Train loss: -0.0354, Validation loss: -0.0564
# No improvement in validation loss. Counter: 79/100
# Epoch 233/1000, Train loss: -0.0411, Validation loss: -0.0564
# No improvement in validation loss. Counter: 80/100
# Epoch 234/1000, Train loss: -0.0417, Validation loss: -0.0564
# No improvement in validation loss. Counter: 81/100
# Epoch 235/1000, Train loss: -0.0397, Validation loss: -0.0564
# No improvement in validation loss. Counter: 82/100
# Epoch 236/1000, Train loss: -0.0371, Validation loss: -0.0564
# No improvement in validation loss. Counter: 83/100
# Epoch 237/1000, Train loss: -0.0399, Validation loss: -0.0564
# No improvement in validation loss. Counter: 84/100
# Epoch 238/1000, Train loss: -0.0398, Validation loss: -0.0564
# No improvement in validation loss. Counter: 85/100
# Epoch 239/1000, Train loss: -0.0437, Validation loss: -0.0564
# No improvement in validation loss. Counter: 86/100
# Epoch 240/1000, Train loss: -0.0401, Validation loss: -0.0564
# No improvement in validation loss. Counter: 87/100
# Epoch 241/1000, Train loss: -0.0397, Validation loss: -0.0564
# No improvement in validation loss. Counter: 88/100
# Epoch 242/1000, Train loss: -0.0338, Validation loss: -0.0564
# No improvement in validation loss. Counter: 89/100
# Epoch 243/1000, Train loss: -0.0401, Validation loss: -0.0564
# No improvement in validation loss. Counter: 90/100
# Epoch 244/1000, Train loss: -0.0329, Validation loss: -0.0564
# No improvement in validation loss. Counter: 91/100
# Epoch 245/1000, Train loss: -0.0360, Validation loss: -0.0564
# No improvement in validation loss. Counter: 92/100
# Epoch 246/1000, Train loss: -0.0352, Validation loss: -0.0564
# No improvement in validation loss. Counter: 93/100
# Epoch 247/1000, Train loss: -0.0371, Validation loss: -0.0564
# No improvement in validation loss. Counter: 94/100
# Epoch 248/1000, Train loss: -0.0426, Validation loss: -0.0564
# No improvement in validation loss. Counter: 95/100
# Epoch 249/1000, Train loss: -0.0376, Validation loss: -0.0564
# No improvement in validation loss. Counter: 96/100
# Epoch 250/1000, Train loss: -0.0462, Validation loss: -0.0564
# No improvement in validation loss. Counter: 97/100
# Epoch 251/1000, Train loss: -0.0378, Validation loss: -0.0564
# No improvement in validation loss. Counter: 98/100
# Epoch 252/1000, Train loss: -0.0403, Validation loss: -0.0564
# No improvement in validation loss. Counter: 99/100
# Epoch 253/1000, Train loss: -0.0370, Validation loss: -0.0564
# No improvement in validation loss. Counter: 100/100
# Early stopping triggered!

# %%
df_test = pd.DataFrame(y_test, columns=['future_returns'])
df_test['returns'] = df_test['future_returns'].shift(1)
df_test['dmn_position'] = y_pred.reshape(-1)
df_test["dmn_ret"] = df_test["dmn_position"] * df_test["future_returns"]
df_test["dmn_cumret"] = (df_test["dmn_ret"]).cumsum()

# %%
print(report_metrics(df_test['dmn_ret']))
# Out:
# {'annual_ret': np.float64(0.028370204771316004), 'annual_std': np.float64(0.037290850005135844), 'annual_sharpe': np.float64(0.7607819282051428)}
